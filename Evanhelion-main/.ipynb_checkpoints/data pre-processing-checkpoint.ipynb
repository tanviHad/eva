# %%
# Load the JSON data into Python
with open('News_Category_Dataset_v3.json') as f:
    data = f.readlines()

# Flatten the JSON data into a tabular format using pandas
df_list = []
for d in data:
    json_data = json.loads(d)
    df = pd.json_normalize(json_data)
    df_list.append(df)

# Concatenate the tabular data into a single DataFrame
df = pd.concat(df_list, ignore_index=True)

# Export the tabular data to a CSV file
df.to_csv('data_test.csv', index=False)

# %%
import pandas as pd
import json
import numpy as np
import os
import matplotlib.pyplot as plt
import random
import math
import scipy.sparse
import sklearn.metrics.pairwise
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation#MiniBatchNMF
from sklearn.datasets import fetch_20newsgroups

# %%
data = pd.read_csv("data.csv")
data.shape
# Out:
# (209527, 6)

# %%
data.dropna(inplace=True)
data.reset_index(drop=True,inplace=True)
data.shape
# Out:
# (156859, 6)

# %%
data.head(1)
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
#
#          date
# 0  23-09-2022

# %% [markdown]
# ## CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
# count vectoriser: allows us to the bag-of -words approach by counting the collection of text documents 
#into matrix of token counts
#Bags of words approach:simple and commonly used way to represent text for we in ML, which ignores 
#structure & only counts how often each word occures
vect = CountVectorizer().fit(data.short_description)
len(vect.get_feature_names())
# Out:
# 68768

# %%
vectorized_word_feature = vect.transform(data.short_description)
vectorized_word_feature
# Out:
# <156859x68768 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3018680 stored elements in Compressed Sparse Row format>

# %%
# get the feature names as numpy array
feature_names = np.array(vect.get_feature_names())
# Sort the coefficients from the model
sorted_coef_index = vectorized_word_feature.max(0).toarray()[0].argsort()

# Find the 10 smallest and 10 largest coefficients
# The 10 largest coefficients are being indexed using [:-11:-1] 
# so the list returned is in order of largest to smallest
print('Smallest Coefs:\n{}\n'.format(feature_names[sorted_coef_index[:10]]))
print('Largest Coefs: \n{}'.format(feature_names[sorted_coef_index[:-11:-1]]))
# Out:
# Smallest Coefs:
# ['kyoto' 'ortigia' 'ortiz' 'orvieto' 'orville' 'orwell' 'orwellian' 'ory'
#  'os' 'osa']
#
# Largest Coefs:
# ['the' 'cake' 'black' 'bodies' 'to' 'it' 'you' 'and' 'of' 'chocolate']

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "max_iter": 300,
    "random_state": 42,
    }

# A list holds the SSE values for each k
sse = []
for k in range(5, 25, 5):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(vectorized_word_feature)
    sse.append(kmeans.inertia_)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(5, 25, 5), sse)
plt.xticks(range(5, 25, 5))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kmeans = KMeans(init="random",n_clusters=10,n_init=10,max_iter=300,random_state=42)
kmeans.fit(vectorized_word_feature)
kmeans.labels_
# Out:
# array([5, 5, 6, ..., 8, 0, 4], dtype=int32)

# %%
data['cluster_label_cnt_vec'] = kmeans.labels_

# %%
data.head(1)
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
#
#          date  cluster_label_cnt_vec
# 0  23-09-2022                      5

# %% [markdown]
# ## Tfidf

# %%
#from sklearn.feature_extraction.text import TfidfVectorizer
# Fit the TfidfVectorizer to the training data specifiying a minimum document frequency of 5
n_samples = 2000
n_features = 1000
n_components = 10
n_top_words = 20
batch_size = 128
init = "nndsvda"

tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=30, max_features=n_features, stop_words="english")
tfidf = tfidf_vectorizer.fit_transform(data.short_description)
#len(tfidf.get_feature_names())

# %%
nmf = NMF(
    n_components=n_components,
    random_state=1,
    init=init,
    beta_loss="frobenius",
    alpha_W=0.00005,
    alpha_H=0.00005,
    l1_ratio=1,
).fit(tfidf)

# %%
def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(2, 5, figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f"Topic {topic_idx +1}", fontdict={"fontsize": 30})
        ax.invert_yaxis()
        ax.tick_params(axis="both", which="major", labelsize=20)
        for i in "top right left".split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()

tfidf_feature_names = tfidf_vectorizer.get_feature_names_out()
plot_top_words(
    nmf,
    tfidf_feature_names,
    n_top_words,
    "Topics in NMF model (generalized Kullback-Leibler divergence)",
)

# %%
lda = LatentDirichletAllocation(
    n_components=n_components,
    max_iter=5,
    learning_method="online",
    learning_offset=50.0,
    random_state=0,
).fit(tfidf)
plot_top_words(
    lda,
    tfidf_feature_names,
    n_top_words,
    "Topics in LDA model (generalized Kullback-Leibler divergence)",
)

# %%
from sklearn.metrics.pairwise import cosine_similarity

target_article = "Fighting beauty standards one photo at a time."
target_article_tfidf = tfidf_vectorizer.transform([target_article])
target_article_topic_dist = lda.transform(target_article_tfidf)

doc_topic_dists = lda.transform(tfidf)
doc_sims = cosine_similarity(target_article_topic_dist, doc_topic_dists)[0]

# Recommend articles
N = 10
docs = [' '.join(row['short_description'].split()) for _, row in data.iterrows()]
top_N_articles = [docs[i] for i in doc_sims.argsort()[::-1][:N]]

# %%
print(top_N_articles)
# Out:
# ['Fighting beauty standards one photo at a time.', 'Experts say insomnia is common after a major scare.', 'A long time ago, in a galaxy not far from Broadway ...', 'Experts already concerned about census response rates say the query would cause even fewer people to respond.', 'Feminism is about making your own choices, even if that choice is something super “un-feministic” like being a SAHM or celebrating physical beauty.', "If you're looking to see the most popular YouTube videos of the week, look no further. We've sifted through the top most", 'Check out this mom version of "The Blair Witch Project."', 'I had no idea how funny divorces could be until I worked for a divorce attorney.', "Although there's much to praise in the Young Vic-Joshua Andrews co-production of Tennessee Wiliams's superb A Street Car Named Desire, now transported to St. Ann's Warehouse, the laurels go mostly to the cast. About other prominent aspects, there's much to question.", 'Take a break from technology this holiday season.']

# %%
vectorized_word_feature = tfidf_vectorizer.transform(data.short_description)
vectorized_word_feature
# Out:
# <156859x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 802699 stored elements in Compressed Sparse Row format>

# %%
feature_names = np.array(tfidf_vectorizer.get_feature_names())

sorted_tfidf_index = vectorized_word_feature.max(0).toarray()[0].argsort()

print('Smallest tfidf:\n{}\n'.format(feature_names[sorted_tfidf_index[:10]]))
print('Largest tfidf: \n{}'.format(feature_names[sorted_tfidf_index[:-11:-1]]))
# Out:
# Smallest tfidf:
# ['spiritual' 'ago' 'opportunity' 'tumblr' 'york' 'treatment' 'aware'
#  'nominee' 'physical' 'muslim']
#
# Largest tfidf:
# ['young' 'florida' 'free' 'fox' 'forward' 'form' 'forget' 'forever'
#  'foreign' 'force']
# /Users/mandali/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "max_iter": 300,
    "random_state": 42,
    }

# A list holds the SSE values for each k
sse = []
for k in range(5, 35, 5):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(vectorized_word_feature)
    sse.append(kmeans.inertia_)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(5, 35, 5), sse)
plt.xticks(range(5, 35, 5))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kmeans = KMeans(init="random",n_clusters=30,n_init=10,max_iter=300,random_state=42)
kmeans.fit(vectorized_word_feature)
kmeans.labels_
# Out:
# array([ 8, 21, 22, ..., 29,  2, 21], dtype=int32)

# %%
vectorized_word_feature[35842]
# Out:
# <1x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>

# %%
kmeans.inertia_
# Out:
# 138044.68728733074

# %%
data['cluster_label_tfidf'] = kmeans.labels_

# %%
data.head(1)
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
#
#          date  cluster_label_tfidf
# 0  23-09-2022                    8

# %%
data.cluster_label_tfidf.value_counts()
# Out:
# 21    80259
# 0      5468
# 6      5024
# 23     4965
# 22     4776
# 12     4704
# 26     4569
# 14     4152
# 19     4086
# 3      3760
# 18     3593
# 11     3281
# 10     3238
# 5      2924
# 2      2624
# 13     2248
# 28     2121
# 8      2105
# 16     2073
# 7      2000
# 25     1413
# 4      1311
# 27     1311
# 24     1292
# 1       753
# 20      685
# 9       582
# 29      577
# 17      518
# 15      447
# Name: cluster_label_tfidf, dtype: int64

# %%
sampling_pool = list(data.index)
init_sample_num = 5
sub_sample_num = 20
init_article = random.sample(sampling_pool,init_sample_num)
init_article
# Out:
# [44157, 20723, 38314, 32092, 139066]

# %%
df = pd.DataFrame(init_article,columns=['relate'])
df
# Out:
#    relate
# 0   44157
# 1   20723
# 2   38314
# 3   32092
# 4  139066

# %%
data.iloc[1].cluster_label_tfidf
# Out:
# 21

# %%
t = pd.DataFrame(data.iloc[0]).T
t = pd.concat([t,t])
t[1:]
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
#
#          date cluster_label_tfidf
# 0  23-09-2022                   8

# %%
for init in init_article:
    c_tag = data.iloc[init].cluster_label_tfidf
    sub_sampling_pool = list(data[data.cluster_label_tfidf==c_tag].index)
    sub_sample_article = random.sample(sub_sampling_pool,sub_sample_num)
    dist_list = []
    init_art_vector = vectorized_word_feature[init]
    for sub_a in sub_sample_article:
        comp_art_vector = vectorized_word_feature[sub_a]
        art_dist = sklearn.metrics.pairwise.pairwise_distances(init_art_vector,comp_art_vector)[0][0]
        dist_list.append(art_dist)

# %%
def generate_user_reading_records(init_sample_num,sub_sample_num,data,vectorized_word_feature):
    sampling_pool = list(data.index)
    init_article = random.sample(sampling_pool,init_sample_num)
    records_df = pd.DataFrame(data.iloc[0]).T
    records_df['art_dist'] = 0
    records_df['init_art'] = 0
    for init in init_article:
        c_tag = data.iloc[init].cluster_label_tfidf
        sub_sampling_pool = list(data[data.cluster_label_tfidf==c_tag].index)
        sub_sample_article = random.sample(sub_sampling_pool,sub_sample_num)
        init_art_vector = vectorized_word_feature[init]
        for sub_a in sub_sample_article:
            comp_art_vector = vectorized_word_feature[sub_a]
            art_dist = sklearn.metrics.pairwise.pairwise_distances(init_art_vector,comp_art_vector)[0][0]
            records_tmp = pd.DataFrame(data.iloc[sub_a]).T
            records_tmp['art_dist'] = art_dist
            records_tmp['init_art'] = init
            records_df = pd.concat([records_df,records_tmp])
    records_df = records_df[1:]
    return records_df

# %%
dt = generate_user_reading_records(init_sample_num,sub_sample_num,data,vectorized_word_feature)

# %%
user_id = 0
reading_records = generate_user_reading_records(init_sample_num,sub_sample_num,data,vectorized_word_feature)
reading_records['user_id'] = user_id
for id_ in range(100):
    reading_records_tmp = generate_user_reading_records(init_sample_num,sub_sample_num,data,vectorized_word_feature)
    reading_records_tmp['user_id'] = id_
    reading_records = pd.concat([reading_records,reading_records_tmp])
reading_records = reading_records[100:]
reading_records.shape
# Out:
# (10000, 10)

# %%
reading_records.head()
# Out:
#                                                      link  \
# 27128   https://www.huffingtonpost.com/entry/the-clima...
# 103121  https://www.huffingtonpost.com/entry/diet-and-...
# 1263    https://www.huffpost.com/entry/bc-us-election-...
# 142925  https://www.huffingtonpost.com/entry/below-the...
# 100522  https://www.huffingtonpost.com/entry/customize...
#
#                                                  headline        category  \
# 27128    The Climate Bomb Lurking Under Arctic Permafrost      WORLD NEWS
# 103121                     The Nutrition and Cancer Myth?  HEALTHY LIVING
# 1263    'A Hell Of A Year': GOP Anticipating A Triumph...        POLITICS
# 142925  Below the Fold: Credit Card Robo-Signers, Bogu...           MONEY
# 100522               Customized Costume Jewelry (#ArtofY)           STYLE
#
#                                         short_description  \
# 27128   New research aims to better understand how muc...
# 103121  An article in the New York Times last Wednesda...
# 1263    Republican leaders are heading into the new ye...
# 142925  According to the New York Times, the debt coll...
# 100522  When Katie launched Three Jane in 2012, she ha...
#
#                                                   authors        date  \
# 27128                          Brian Owens, Arctic Deeply  03-08-2017
# 103121  Joel Fuhrman, M.D., Contributor#1 New York Tim...  29-04-2014
# 1263                  Steve Peoples and Will Weissert, AP  31-12-2021
# 142925  Richard Zombeck, Contributor\nRichard Zombeck ...  23-08-2012
# 100522  Alex Schattner, ContributorWeb Developer / Des...  02-07-2014
#
#        cluster_label_tfidf  art_dist  init_art  user_id
# 27128                    6  1.343187    118880        0
# 103121                   6  1.390514    118880        0
# 1263                     6  1.363746    118880        0
# 142925                   6  1.358587    118880        0
# 100522                   6  1.338146    118880        0

# %%
distinct_categories = reading_records['category'].drop_duplicates().tolist()
reading_records['category_id'] = reading_records['category'].apply(lambda x: distinct_categories.index(x))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
reading_records['category_id'] = scaler.fit_transform(reading_records[['category_id']])

# %%
reading_records['category_rate'] = reading_records['category_id']+ reading_records['art_dist']
reading_records['category_rate_norm'] = scaler.fit_transform(reading_records[['category_rate']])
reading_records
# Out:
#                                                      link  \
# 27128   https://www.huffingtonpost.com/entry/the-clima...
# 103121  https://www.huffingtonpost.com/entry/diet-and-...
# 1263    https://www.huffpost.com/entry/bc-us-election-...
# 142925  https://www.huffingtonpost.com/entry/below-the...
# 100522  https://www.huffingtonpost.com/entry/customize...
# ...                                                   ...
# 140710  https://www.huffingtonpost.com/entry/yoga-rout...
# 97863   https://www.huffingtonpost.com/entry/barbecuin...
# 86528   https://www.huffingtonpost.com/entry/why-latin...
# 155901  https://www.huffingtonpost.com/entry/post_us_5...
# 20967   https://www.huffingtonpost.com/entry/this-body...
#
#                                                  headline        category  \
# 27128    The Climate Bomb Lurking Under Arctic Permafrost      WORLD NEWS
# 103121                     The Nutrition and Cancer Myth?  HEALTHY LIVING
# 1263    'A Hell Of A Year': GOP Anticipating A Triumph...        POLITICS
# 142925  Below the Fold: Credit Card Robo-Signers, Bogu...           MONEY
# 100522               Customized Costume Jewelry (#ArtofY)           STYLE
# ...                                                   ...             ...
# 140710           National Yoga Month Celebration Practice        WELLNESS
# 97863                         Barbecuing and Grilling 101           TASTE
# 86528         Why Latinos Should Speak Up for Black Lives   LATINO VOICES
# 155901                          Nose-To-Tail Event Design        WEDDINGS
# 20967   This Woman Is ‘Chinning’ Her Way Around The Wo...          TRAVEL
#
#                                         short_description  \
# 27128   New research aims to better understand how muc...
# 103121  An article in the New York Times last Wednesda...
# 1263    Republican leaders are heading into the new ye...
# 142925  According to the New York Times, the debt coll...
# 100522  When Katie launched Three Jane in 2012, she ha...
# ...                                                   ...
# 140710  September is National Yoga Month and a time to...
# 97863   Here's my official crash course on barbecuing ...
# 86528   It's time that we, as Latinos, boldly speak ou...
# 155901  The next time you are about to throw away what...
# 20967      Fighting beauty standards one photo at a time.
#
#                                                   authors        date  \
# 27128                          Brian Owens, Arctic Deeply  03-08-2017
# 103121  Joel Fuhrman, M.D., Contributor#1 New York Tim...  29-04-2014
# 1263                  Steve Peoples and Will Weissert, AP  31-12-2021
# 142925  Richard Zombeck, Contributor\nRichard Zombeck ...  23-08-2012
# 100522  Alex Schattner, ContributorWeb Developer / Des...  02-07-2014
# ...                                                   ...         ...
# 140710  Kristin McGee, Contributor\nCelebrity Yoga and...  26-09-2012
# 97863   Steven Raichlen, ContributorGrilling Authority...  05-09-2014
# 86528   Alberto Retana, ContributorAlberto Retana, Exe...  07-05-2015
# 155901       Kristian Gustavson, Contributor\nContributor  10-02-2012
# 20967                                       Elyse Wanshel  24-10-2017
#
#        cluster_label_tfidf  art_dist  init_art  user_id  category_id  \
# 27128                    6  1.343187    118880        0     0.000000
# 103121                   6  1.390514    118880        0     0.024390
# 1263                     6  1.363746    118880        0     0.048780
# 142925                   6  1.358587    118880        0     0.073171
# 100522                   6  1.338146    118880        0     0.097561
# ...                    ...       ...       ...      ...          ...
# 140710                  26  1.366525     95439       99     0.243902
# 97863                   26  1.353654     95439       99     0.804878
# 86528                   26  1.369657     95439       99     0.878049
# 155901                  26  1.326997     95439       99     0.951220
# 20967                   26  1.335908     95439       99     0.219512
#
#         category_rate  category_rate_norm
# 27128        1.343187            0.551838
# 103121       1.414904            0.581848
# 1263         1.412527            0.580853
# 142925       1.431758            0.588900
# 100522       1.435707            0.590553
# ...               ...                 ...
# 140710       1.610427            0.663663
# 97863        2.158532            0.893012
# 86528        2.247706            0.930326
# 155901       2.278216            0.943093
# 20967        1.555420            0.640646
#
# [10000 rows x 13 columns]

# %%
from surprise import Dataset, Reader, KNNBasic
from surprise.model_selection import train_test_split

reader = Reader(rating_scale=(0, 1))
data = Dataset.load_from_df(reading_records[['user_id', 'short_description', 'category_rate_norm']], reader)
trainset, testset = train_test_split(data, test_size=0.2)
algo = KNNBasic()
algo.fit(trainset)

predictions = algo.test(testset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
import seaborn as sns

predictions_df = pd.DataFrame(predictions, columns=['user_id', 'short_description', 'actual_rating', 'predicted_rating', 'details'])
testset_df = pd.DataFrame(testset, columns=['user_id', 'short_description', 'rating'])
merged_df = pd.merge(predictions_df, testset_df, on=['user_id', 'short_description'])

# Plot the predicted vs actual ratings
sns.scatterplot(data=merged_df, x='predicted_rating', y='rating')
plt.xlabel('Predicted Rating')
plt.ylabel('Actual Rating')
plt.show()

# %%
#Used NN 
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

X_train, X_test, y_train, y_test = train_test_split(reading_records["short_description"], reading_records["category_rate_norm"], test_size=0.2)
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
model = Sequential()
model.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %% [markdown]
# ## n-grams

# %%
vect = CountVectorizer(min_df=5, ngram_range=(1,2)).fit(data.short_description)
vectorized_word_feature = vect.transform(data.short_description)
len(vect.get_feature_names())
# Out:
# /Users/summerwang/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 108550

# %%
vectorized_word_feature = vect.transform(data.short_description)
vectorized_word_feature
# Out:
# <156859x108550 sparse matrix of type '<class 'numpy.int64'>'
# 	with 4889593 stored elements in Compressed Sparse Row format>

# %%
feature_names = np.array(vect.get_feature_names())

sorted_ngrams_index = vectorized_word_feature.max(0).toarray()[0].argsort()

print('Smallest tfidf:\n{}\n'.format(feature_names[sorted_ngrams_index[:10]]))
print('Largest tfidf: \n{}'.format(feature_names[sorted_ngrams_index[:-11:-1]]))
# Out:
# Smallest tfidf:
# ['marry him' 'pine' 'pinch' 'pimp' 'pillows' 'pillow and' 'pillars of'
#  'pillars' 'pillar of' 'pillar']
#
# Largest tfidf:
# ['the' 'cake' 'black' 'to' 'bodies' 'chocolate' 'and' 'it' 'of' 'you']

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "max_iter": 300,
    "random_state": 42,
    }

# A list holds the SSE values for each k
sse = []
for k in range(5, 25, 5):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(vectorized_word_feature)
    sse.append(kmeans.inertia_)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(5, 25, 5), sse)
plt.xticks(range(5, 25, 5))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kmeans = KMeans(init="random",n_clusters=10,n_init=10,max_iter=300,random_state=42)
kmeans.fit(vectorized_word_feature)
kmeans.labels_
# Out:
# array([0, 0, 2, ..., 1, 4, 9], dtype=int32)

# %%
data['cluster_label_ngrams'] = kmeans.labels_

# %%
data.head(1)
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
#
#          date  cluster_label_cnt_vec  cluster_label_tfidf  \
# 0  23-09-2022                      5                    3
#
#    cluster_label_ngrams
# 0                     0

# %%
data.cluster_label_cnt_vec.value_counts()
# Out:
# 6    56691
# 8    27472
# 0    23358
# 2    12364
# 5     9347
# 4     9239
# 3     8004
# 1     6207
# 7     3910
# 9      267
# Name: cluster_label_cnt_vec, dtype: int64

# %%
data.cluster_label_tfidf.value_counts()
# Out:
# 5    54817
# 4    34514
# 1    13823
# 9    13397
# 6    10437
# 8     9147
# 7     7773
# 0     6870
# 3     5471
# 2      610
# Name: cluster_label_tfidf, dtype: int64

# %%
data.cluster_label_ngrams.value_counts()
# Out:
# 2    55953
# 1    27347
# 4    23195
# 7    13018
# 9     9358
# 0     9319
# 8     8149
# 5     6318
# 6     3949
# 3      253
# Name: cluster_label_ngrams, dtype: int64

# %%
#https://realpython.com/k-means-clustering-python/
#https://www.kaggle.com/code/jojushaji/sentimental-analysis-on-amazon-reviews/notebook
#https://scikit-learn.org/stable/auto_examples/cluster/plot_cluster_comparison.html#sphx-glr-auto-examples-cluster-plot-cluster-comparison-py

# %%
# using tfidf
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.8, min_samples=500)
dbscan.fit(vectorized_word_feature)
# Out:
# DBSCAN(eps=0.8, min_samples=500)

# %%
data['cluster_label_dbscan'] = dbscan.labels_
data.cluster_label_dbscan.value_counts()
# Out:
# -1    156294
#  0       565
# Name: cluster_label_dbscan, dtype: int64
